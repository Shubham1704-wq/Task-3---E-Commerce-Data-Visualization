# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.bar(category_sales["CategoryName"], category_sales["Revenue"])
plt.title("Revenue by Product Category")
plt.xlabel("Product Category")
plt.ylabel("Revenue")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(monthly_sales["Month"], monthly_sales["Revenue"], marker="o")
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Revenue")
plt.xticks(rotation=45, ha="right")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.pie(
    category_sales["Revenue"],
    labels=category_sales["CategoryName"],
    autopct="%1.1f%%",
    startangle=90
)
plt.title("Revenue Share by Product Category")
plt.tight_layout()
plt.savefig("/content/cleaned_data/revenue_share_by_category.png", dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(16, 10))
fig.suptitle("E-Commerce Sales Dashboard", fontsize=20)

grid = fig.add_gridspec(3, 2, height_ratios=[0.8, 2, 2])

ax1 = fig.add_subplot(grid[0, 0])
ax2 = fig.add_subplot(grid[0, 1])
ax3 = fig.add_subplot(grid[1, 0])
ax4 = fig.add_subplot(grid[1, 1])
ax5 = fig.add_subplot(grid[2, :])

ax1.axis("off")
ax1.text(0.5, 0.6, "Total Revenue", ha="center", fontsize=14)
ax1.text(0.5, 0.25, f"{total_revenue:,.2f}", ha="center", fontsize=18)

ax2.axis("off")
ax2.text(0.5, 0.6, "Total Orders", ha="center", fontsize=14)
ax2.text(0.5, 0.25, f"{total_orders:,}", ha="center", fontsize=18)

ax3.bar(category_sales["CategoryName"], category_sales["Revenue"])
ax3.set_title("Revenue by Category")
ax3.set_xlabel("Category")
ax3.set_ylabel("Revenue")
ax3.tick_params(axis="x", rotation=35)

ax4.plot(monthly_sales["Month"], monthly_sales["Revenue"], marker="o")
ax4.set_title("Monthly Sales Trend")
ax4.set_xlabel("Month")
ax4.set_ylabel("Revenue")
ax4.tick_params(axis="x", rotation=45)
ax4.grid(True)

ax5.axis("off")
ax5.text(0.02, 0.85, "Key Findings", fontsize=16, weight="bold")
ax5.text(0.02, 0.62, f"Total Units Sold: {total_units_sold:,}", fontsize=13)
ax5.text(0.02, 0.43, f"Top Category: {top_category}", fontsize=13)
ax5.text(0.02, 0.24, f"Best Product: {best_product}", fontsize=13)
ax5.text(0.02, 0.05, "Dashboard created from the cleaned sales dataset.", fontsize=11)

plt.tight_layout()
plt.savefig("/content/cleaned_data/dashboard_mockup.png", dpi=300)
plt.show()

# %%
highest_month = monthly_sales.loc[monthly_sales["Revenue"].idxmax()]
lowest_month = monthly_sales.loc[monthly_sales["Revenue"].idxmin()]

highest_category = category_sales.iloc[0]
highest_product = product_sales.iloc[0]

interpretations = f"""
Visualization Interpretations

1. Revenue by Product Category
The category with the highest recorded revenue is {highest_category["CategoryName"]}, with revenue of {highest_category["Revenue"]:,.2f}.

2. Monthly Sales Trend
The highest recorded monthly revenue occurred in {highest_month["Month"]}, with revenue of {highest_month["Revenue"]:,.2f}.
The lowest recorded monthly revenue occurred in {lowest_month["Month"]}, with revenue of {lowest_month["Revenue"]:,.2f}.
Revenue varies across the months shown.

3. Revenue Share by Product Category
The pie chart compares each product category's share of total recorded revenue.

4. Dashboard Mockup
The dashboard brings together key sales KPIs, category revenue and the monthly sales trend in one view.
"""

with open("/content/cleaned_data/chart_interpretations.txt", "w") as file:
    file.write(interpretations.strip())

print(interpretations)
print("\nInterpretations saved successfully.")
# Out:
# Visualization Interpretations
#
# 1. Revenue by Product Category
# The category with the highest recorded revenue is Storage, with revenue of 10,712,932.17.
#
# 2. Monthly Sales Trend
# The highest recorded monthly revenue occurred in 2017-02, with revenue of 4,573,355.78.
# The lowest recorded monthly revenue occurred in 2017-06, with revenue of 134,097.68.
# Revenue varies across the months shown.
#
# 3. Revenue Share by Product Category
# The pie chart compares each product category's share of total recorded revenue.
#
# 4. Dashboard Mockup
# The dashboard brings together key sales KPIs, category revenue and the monthly sales trend in one view.
#
#
# Interpretations saved successfully.

# %%
import os

for file_name in sorted(os.listdir("/content/cleaned_data")):
    print(file_name)
# Out:
# Customer_cleaned.csv
# Employee_cleaned.csv
# OrderDetails_cleaned.csv
# Orders_cleaned.csv
# Product_cleaned.csv
# Region_cleaned.csv
# Sales_Data_Cleaned.csv
# Warehouse_cleaned.csv
# chart_interpretations.txt
# cleaning_decisions.txt
# cleaning_summary.csv
# dashboard_mockup.png
# kpi_summary.csv
# revenue_share_by_category.png
# validation_report.csv

# %% [markdown]
# ## Task 3: Interpretation of Visualizations
#
# ### 1. Bar Chart — Revenue by Product Category
#
# The bar chart compares the revenue earned by different product categories. Storage is the category with the highest recorded revenue. This helps us understand which category contributed the most to sales.
#
# ### 2. Line Chart — Monthly Sales Trend
#
# The line chart shows how revenue changed from month to month. February 2017 had the highest recorded monthly revenue, while June 2017 had the lowest among the months displayed. This shows that sales revenue varied over time.
#
# ### 3. Pie Chart — Revenue Share by Product Category
#
# The pie chart shows how total recorded revenue is divided among the product categories. Each slice represents the share contributed by one category. This makes it easier to compare the categories' contributions to revenue.
#
# ### 4. Dashboard Mockup
#
# The dashboard brings important sales information together in one place. It displays key figures, category revenue and the monthly sales trend. This helps a viewer understand the main results without checking each table separately.
